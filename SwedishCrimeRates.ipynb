# %%
# %matplotlib inline 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("reported.csv")

# %%
df.head()

# %%
df.fillna(0, inplace=True)

# %%
df.head()

# %%
df.tail()
# Out:
#     Year  crimes.total  crimes.penal.code  crimes.person  murder  assault  \
# 61  2011         14988              12267           1005       2      947
# 62  2012         14734              12148            974       2      914
# 63  2013         14603              12072            896       3      837
# 64  2014         14890              12305            923       3      859
# 65  2015         15342              12803            932       3      868
#
#     sexual.offenses  rape  stealing.general  burglary     ...      \
# 61              181    69              5783       995     ...
# 62              178    66              5613       922     ...
# 63              184    63              5552       888     ...
# 64              210    69              5572       913     ...
# 65              184    60              5404       917     ...
#
#     vehicle.theft  out.of.vehicle.theft  shop.theft  robbery  fraud  \
# 61          213.0                 706.0       663.0      103   1220
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("reported.csv")
df.fillna(0, inplace=True)

fig, ax = plt.subplots()
ax.plot(df["Year"], df["crimes.total"])
ax.plot(df["Year"], df["population"])
ax.set_title("Crimes: Total x Population")
ax.legend()
ax.set_ylabel("Total crimes")
ax.set_xlabel("Year")
plt.show()

fig, ax = plt.subplots()
ax.plot(df["Year"], df["sexual.offenses"])
ax.plot(df["Year"], df["rape"])
ax.set_title("Crimes: Sexual Offenses x Rape")
ax.legend()
ax.set_ylabel("Total crimes")
ax.set_xlabel("Year")
plt.show()



fig, ax = plt.subplots()
ax.plot(df["Year"], df["burglary"])
ax.plot(df["Year"], df["vehicle.theft"])
ax.plot(df["Year"], df["out.of.vehicle.theft"])
ax.plot(df["Year"], df["shop.theft"])
ax.plot(df["Year"], df["robbery"])
ax.legend()
ax.set_ylabel("Total crimes")
ax.set_xlabel("Year")
plt.show()

fig, ax = plt.subplots()
ax.plot(df["Year"], df["stealing.general"])
ax.plot(df["Year"], df["burglary"])
ax.plot(df["Year"], df["vehicle.theft"])
ax.plot(df["Year"], df["out.of.vehicle.theft"])
ax.plot(df["Year"], df["shop.theft"])
ax.plot(df["Year"], df["robbery"])
ax.plot(df["Year"], df["house.theft"])
ax.legend()
ax.set_ylabel("Total crimes")
ax.set_xlabel("Year")
plt.show()


fig, ax = plt.subplots()
ax.plot(df["Year"], df["drunk.driving"])
ax.plot(df["Year"], df["narcotics"])
ax.legend()
ax.set_ylabel("Total crimes")
ax.set_xlabel("Year")
plt.show


fig, ax = plt.subplots()
ax.plot(df["Year"], df["drunk.driving"])
ax.plot(df["Year"], df["narcotics"])
ax.legend()
ax.set_ylabel("Total crimes")
ax.set_xlabel("Year")
plt.show()


fig, ax = plt.subplots()
ax.plot(df["Year"], df["murder"])
ax.plot(df["Year"], df["assault"])
ax.plot(df["Year"], df["crimes.person"])
ax.legend()
ax.set_title("Personal Crimes")
ax.set_ylabel("Total crimes")
ax.set_xlabel("Year")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("reported.csv")
df.fillna(0, inplace=True)

fig, ax = plt.subplots()
ax.plot(df["Year"], df["sexual.offenses"])
ax.plot(df["Year"], df["rape"])
ax.set_title("Sexual Crimes")
ax.set_ylabel("Total Crimes")
ax.set_xlabel("Year")
ax.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("reported.csv")
df.fillna(0, inplace=True)

fig, ax = plt.subplots()
ax.plot(df["Year"], df["sexual.offenses"])
ax.plot(df["Year"], df["rape"])
ax.set_title("Thefts")
ax.set_title("Sexual Crimes")
ax.set_ylabel("Total Crimes")
ax.set_xlabel("Year")
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(df["Year"], df["burglary"])
ax.plot(df["Year"], df["vehicle.theft"])
ax.plot(df["Year"], df["out.of.vehicle.theft"])
ax.plot(df["Year"], df["shop.theft"])
ax.plot(df["Year"], df["robbery"])
ax.legend()
ax.set_ylabel("Total crimes")
ax.set_xlabel("Year")
plt.show()

fig, ax = plt.subplots()
ax.plot(df["Year"], df["stealing.general"])*
ax.plot(df["Year"], df["burglary"])*
ax.plot(df["Year"], df["vehicle.theft"])*
ax.plot(df["Year"], df["out.of.vehicle.theft"])*
ax.plot(df["Year"], df["shop.theft"])*
ax.plot(df["Year"], df["robbery"])*
ax.plot(df["Year"], df["house.theft"])*
ax.legend()
ax.set_ylabel("Total crimes")
ax.set_xlabel("Year")
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(df["Year"], df["drunk.driving"])
ax.plot(df["Year"], df["narcotics"])

ax.legend()
ax.set_ylabel("Total crimes")
ax.set_xlabel("Year")
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(df["Year"], df["murder"])
ax.plot(df["Year"], df["assault"])
ax.plot(df["Year"], df["crimes.person"])
ax.legend()
ax.set_title("Personal Crimes")
ax.set_ylabel("Total crimes")
ax.set_xlabel("Year")
plt.show()

# %%
df['Sexual Crimes'] = df['rape'] + df['sexual.offenses']
df['Theft'] = df["stealing.general"] + df['burglary'] + df['vehicle.theft'] + df['out.of.vehicle.theft'] + df['shop.theft'] + df['robbery'] + df['house.theft']
df['Personal Crimes'] = df['crimes.person'] + df['assault'] + df['murder']
df['Substance Abuse'] = df['drunk.driving'] + df['narcotics']

fig, ax = plt.subplots()
ax.plot(df["Year"], df["Sexual Crimes"])
ax.plot(df["Year"], df["Theft"])
ax.plot(df["Year"], df["Personal Crimes"])
ax.plot(df["Year"], df["Substance Abuse"])
ax.legend()
ax.set_title("Overall")
ax.set_ylabel("Total crimes")
ax.set_xlabel("Year")
plt.show()




df['Sexual Crimes'] = df['rape'] + df['sexual.offenses']
df['Theft'] = df["stealing.general"] + df['burglary'] + df['vehicle.theft'] + df['out.of.vehicle.theft'] + df['shop.theft'] + df['robbery'] + df['house.theft']
df['Personal Crimes'] = df['crimes.person'] + df['assault'] + df['murder']
df['Substance Abuse'] = df['drunk.driving'] + df['narcotics']
fig, ax = plt.subplots()
ax.plot(df["Year"], df["Sexual Crimes"])
ax.plot(df["Year"], df["Theft"])
ax.plot(df["Year"], df["Personal Crimes"])
ax.plot(df["Year"], df["Substance Abuse"])
ax.plot(df["Year"], df["population"])
ax.legend()
ax.set_title("Total Crimes vs Sweden Population")
ax.set_ylabel("Total crimes")
ax.set_xlabel("Year")
plt.show()
